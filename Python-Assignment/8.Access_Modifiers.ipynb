# %% [markdown]
# 1. Create a class with PRIVATE fields, private method and a main method. Print the fields
# in main method. Call the private method in main method.
# Create a sub class and try to access the private fields and methods from sub class

# %%
class A:
    def __init__(self , age , name):
        self.__age = age #private variable 
        self.__name = name

    
    def __private_functon(self):
        print("this method is private")

   
    def main(self):#as said the main method is inside the class


        print(f"Name = {self.__name}")
        print(f"age = {self.__age}")

        self.__private_functon()
    

obj = A(19 , "kartikey")
obj.main()


class B(A):
    def __init__(self, age, name):
        super().__init__(age, name)

    def display(self):  
        print(self._A__name) #this is how you acceess a name from a private class and i have no idea how to untill now 


obj2 = B(19 , "hanisha")
obj2.display()
# Out:
# Name = kartikey
# age = 19
# this method is private
# hanisha

# %% [markdown]
# 2. Create a class with PROTECTED fields and methods. Access these fields and methods
# from any other class in the same package.
# Also, Access the PROTECTED fields and methods from child class located in a different
# package
# Access the PROTECTED fields and methods from any class in different package

# %%
class protected:
    def __init__(self , name,age):
        self._name = name
        self._age = age

    def public_finction(self):
        print("My name is",self._name)
        print("My age is", self._age)


obj = protected("kartikey",19)
print(obj._name) #still can be accessed without any problem
print(obj._age)

print(obj.public_finction())
# Out:
# kartikey
# 19
# My name is kartikey
# My age is 19
# None

# %% [markdown]
# 3. Create a class with PUBLIC fields and methods.
# Access the public methods and fields from any class in the same package or different
# package.

# %%
class public:
    def __init__(self , name,age):
        self.name = name
        self.age = age

    def public_finction(self):
        print("My name is",self.name)
        print("My age is", self.age)

    
obj = public("kartikey",19)
print(obj.name)
print(obj.age)

print(obj.public_finction())
# Out:
# kartikey
# 19
# My name is kartikey
# My age is 19
# None
